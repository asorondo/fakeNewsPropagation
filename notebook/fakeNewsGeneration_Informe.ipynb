# %% [markdown]
# # Tabla de contenidos
#
# * [Instalación del simulador CD++](#instalacionCD++)
# * [Simulador CD++](#simuladorCD++)
# * [Ejemplos en CD++](#ejemplosCD++)
# * [Scripts útiles](#scripts)
# * [Hola Mundo!](#holamundo)

# %%
try:
    import pandas as pd
except:
    # !pip install pandas
    import pandas as pd

# %%
try:
    import scipy as sp
except:
    # !pip install scipy
    import scipy as sp

# %%
try:
    import matplotlib.pyplot as plt
except:
    # !pip install matplotlib
    import matplotlib.pyplot as plt

# %%
# definimos los path a los archivos de interés
OUT_FILENAME = "../fakeNewsPropagation.out"

# con el script tuple_to_real elegimos el índice 0 de la 3-upla
# tuple_to_real.tuple_to_real(OUT_FILENAME, 0)

# definimos los nombres de las columnas en los dataframes de pandas
TIME_COL_ORIG = 'time_orig'
TIME_COL = 'time'
PORT_COL = 'port'
VALUE_COL_ORIG = 'value_orig'
VALUE_COL = 'value'
POPULATION_COL = 'population'
POLITICAL_AFFINITY = 'political_affinity'
MESSAGE_TYPE_COL = 'message_type'
MODEL_ORIGIN_COL = 'model_origin'
MODEL_DEST_COL = 'model_dest'

# parsea cada fila del dataframe
def parse_value(value):
    is_list = value.strip().startswith("[") and value.strip().endswith("]")
    if is_list:
        return tuple(float(num) for num in value.replace('[', '').replace(']', '').split(', '))
    return float(value)

#conversion VTime a float
def time_to_secs(time):
    h, m, s, ms, r = time.split(':')
    return float(h)*60*60. + float(m)*60. + float(s) + float(ms)/1000. + float(r)/1000.

#conversion string to list
def value_to_list(value):
    tempValue = value[1:-1]
    return tempValue.split(',')

df_converters = {
     VALUE_COL: parse_value,
     TIME_COL: time_to_secs
 }

salida = pd.read_csv(OUT_FILENAME,
                     delimiter=r'(?<!,)\s+',
                     engine='python',  # C engine doesnt work for regex
                     # Se puede usar esto para convertir los valores directamente:
                     # converters=df_converters,
                     names=[TIME_COL_ORIG, PORT_COL, VALUE_COL_ORIG]
                    )

salida[TIME_COL]  = salida.apply(lambda row: time_to_secs(row[TIME_COL_ORIG]), axis=1)
salida[VALUE_COL] = salida.apply(lambda row: value_to_list(str(row[VALUE_COL_ORIG])), axis=1)
salida[POPULATION_COL] = salida.apply(lambda row: value_to_list(str(row[VALUE_COL_ORIG]))[0], axis=1)
salida[POLITICAL_AFFINITY] = salida.apply(lambda row: value_to_list(str(row[VALUE_COL_ORIG]))[1], axis=1)


outs_estadisticos = salida.loc[ salida['value'].str.len() == 2]
population3 = outs_estadisticos.loc[ salida['population'] == '3']
population3.head()
# Out:
#          time_orig      port     value_orig    time           value  \
# 1   00:00:01:035:0  out_port  [3, 0.995788]   1.035  [3,  0.995788]
# 3   00:00:02:051:0  out_port   [3, 0.96785]   2.051   [3,  0.96785]
# 5   00:00:03:015:0  out_port  [3, 0.881442]   3.015  [3,  0.881442]
# 17  00:00:09:018:0  out_port  [3, 0.670089]   9.018  [3,  0.670089]
# 23  00:00:12:025:0  out_port   [3, 0.72254]  12.025   [3,  0.72254]
#
#    population political_affinity
# 1           3           0.995788
# 3           3            0.96785
# 5           3           0.881442
# 17          3           0.670089
# 23          3            0.72254

# %%
y_strings = population3[POLITICAL_AFFINITY].tolist()
x_string = population3[TIME_COL].tolist()
y_values = list(map(float, y_strings))
x_values = list(map(float, x_string))

plt.figure(figsize=(10,5))
plt.plot(x_values, y_values,marker='x')
plt.grid(True)
plt.xlabel('Tiempo [s]')
plt.ylabel('Valor')
plt.title('Evolucion de la afinidad politica de la poblacion 3');

# %% [markdown]
# # Bibliotecas de Python
#
# En este notebook vamos a utilizar las siguientes bibliotecas de Python:
# * pathlib
# * pandas
# * scipy
# * matplotlib
#
# Para instalarlas podemos correr la siguiente línea (si están usando un *venv* deben correrlo dentro del entorno virtual):
#
# ```
# $ pip install pathlib pandas matplotlib scipy
# ```

# %%
# %%bash -s "$CDPP_SRC"
#
# ls
# Out:
# 00 - primeros_pasos_resultados_2021-Copy1.ipynb

# %% [markdown]
# <a id='instalacionCD++'></a>
# # Instalación del simulador CD++
#
# ## Máquina virtual
#
# Pueden descargar la máquina virtual de la materia con todas las herramientas de simulación que utilizaremos a lo largo del curso ya instaladas:
# ```
# ftp://modsimu.exp.dc.uba.ar/VM2021
# ```
#
# Luego, para correr por ejemplo jupyter-lab lo hacen desde dentro de un entorno virtual:
#
# ```
# source .env37/bin/activate
# jupyter-lab
# ```

# %% [markdown]
# ## Descarga
#
# La forma más senclla de obtener el código fuente del simulador es clonando el repositorio git:
#
# ```
#  $ git clone https://github.com/SimulationEverywhere/CDPP_ExtendedStates-codename-Santi.git
# ```
#
#
# Descargamos el simulador del repositorio [SimulationEverywhere](https://github.com/SimulationEverywhere/CDPP_ExtendedStates-codename-Santi)

# %%
try:
    from pathlib import Path
except:
    # !pip install pathlib
    from pathlib import Path

# %%
SED_HOME = Path.home().joinpath('SED')
# SED_HOME = 'user/SED/'
# URL del repositorio de cd++
CDPP_REPO = 'https://github.com/SimulationEverywhere/CDPP_ExtendedStates-codename-Santi.git'

# %%
# %%bash -s "$SED_HOME" "$CDPP_REPO"
#
# # $1 es el directorio donde vamos a clonar el cd++ (CDPP_DIR)
# # $2 la URL del repo (CDPP_REPO)
#
# # si el directorio existe, no hago nada, caso contrario, creo la carpeta
# [ -d $1 ] || mkdir -p $1
# cd $1
#
# # si el directorio existe, no hago nada, caso contrario, traigo el simu con git clone
# [ -d CDPP_ExtendedStates-codename-Santi ] || git clone $2
#
# echo "Finalizado!"
# Out:
# Finalizado!

# %%
#Directorio base donde está instalado el siumulador
CDPP_DIR = SED_HOME.joinpath('CDPP_ExtendedStates-codename-Santi')
# CDPP_DIR = SED_HOME+'CDPP_ExtendedStates-codename-Santi'

# %% [markdown]
# ### Prerequisitos
#
# Para instalar el simulador necesitamos tener instaladas ls siguientes bibliotecas:
#
#  * `GCC 4.7` or higher (with C++11 support)
#  * `bison`
#  * `GNU make`
#
#  La forma más sencilla es utilizando apt:
#
#  ```
#  $ sudo apt install build-essential bison
#  ```

# %% [markdown]
# ## Compilación
#
# Para compilar el _kernel_ del simulador, vamos al directorio en donde está ubicado el código fuente y corremos make:
#
# ```
#  $ cd $CDPP_DIR/CDPP_ExtendedStates-codename-Santi/src
#  $ make
# ```

# %%
CDPP_SRC = CDPP_DIR.joinpath('src')

# %%
# %%bash -s "$CDPP_SRC"
#
# cd $1
#
# ls
#
# # limpiamos compilaciones viejas si las hay
# make clean
#
# # compilamos cd++ (esto demora unos minutos y no se ve ninguna salida... sólo mensajes de g++ y warnings al final)
# make -j4
# Out:
# bin
# cd++
# Makefile
# tools
# make -C cd++ clean OBJ_DIR=obj
# make[1]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics'
# make -C cpu clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu'
# make -C queue clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue'
# make -C qss clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss'
# make -C generator clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator'
# make -C transducer clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc'
# make -C math clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model'
# make -C state clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser'
# make -C cdlang clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc'
# make -C state clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim'
# make -C loader clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils'
# make -C log clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped'
# make -C common clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common'
# make -C notime clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped'
# make[1]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++'
# make -C tools clean OBJ_DIR=obj
# make[1]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools'
# make -C drawlog clean OBJ_DIR=obj
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/drawlog'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/drawlog'
# make -C makerand clean OBJ_DIR=obj
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/makerand'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/makerand'
# make -C parlog clean OBJ_DIR=obj
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/parlog'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/parlog'
# make -C toCDPP clean OBJ_DIR=obj
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/toCDPP'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/toCDPP'
# make -C toMap clean OBJ_DIR=obj
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/toMap'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools/toMap'
# make[1]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/tools'
# make -C cd++ OUT_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/bin OBJ_DIR=obj
# make[1]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics'
# make -C cpu OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make -C queue OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue'
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt'
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  cpu.cpp -o obj/cpu.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  queue.cpp -o obj/queue.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  pmessage.cpp -o obj/pmessage.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  tdcell.cpp -o obj/tdcell.o
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt'
# make -C qss OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue'
# make -C math OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  zone.cpp -o obj/zone.o
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math'
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  qss3.cpp -o obj/qss3.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  distri.cpp -o obj/distri.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  except.cpp -o obj/except.o
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model'
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  realfunc.cpp -o obj/realfunc.o
# make -C state OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state'
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  atomicstate.cpp -o obj/atomicstate.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  qss_utils.cpp -o obj/qss_utils.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  coupcell.cpp -o obj/coupcell.o
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state'
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  prootmodel.cpp -o obj/prootmodel.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  coupled.cpp -o obj/coupled.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt   -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  qss1.cpp -o obj/qss1.o
# gcc -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj    -g -O0   com.c -o obj/com.o
# ...
# com.c:331:5: note: include ‘<stdlib.h>’ or provide a declaration of ‘exit’
# com.c: In function ‘setsd’:
# com.c:368:5: warning: incompatible implicit declaration of built-in function ‘exit’
#   368 |     exit(1);
#       |     ^~~~
# com.c:368:5: note: include ‘<stdlib.h>’ or provide a declaration of ‘exit’
# In file included from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tbool.h:21,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/real.h:22,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/strutil.h:28,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/pmodeladm.h:29,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/port.h:25,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/model.h:26,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/atomic.h:24,
#                  from qss1.h:6,
#                  from qss1.cpp:8:
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h: In instantiation of ‘const T& Tuple<T>::operator[](int) const [with T = Real]’:
# qss1.cpp:57:52:   required from here
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h:59:30: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Real, std::allocator<Real> >::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#    59 |  MASSERT(index >= 0 && index < this->values.size());
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/except.h:32:30: note: in definition of macro ‘MASSERT’
#    32 | #define MASSERT(lexp) if( !( lexp ) ) { AssertException e( "Invalid assertion" ) ; e.addText( #lexp ) ; e.addLocation( MEXCEPTION_LOCATION() ) ; throw e ; }
#       |                              ^~~~
# In file included from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tbool.h:21,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/real.h:22,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/strutil.h:28,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/pmodeladm.h:29,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/port.h:25,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/model.h:26,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/atomic.h:24,
#                  from qss2.h:6,
#                  from qss2.cpp:8:
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h: In instantiation of ‘const T& Tuple<T>::operator[](int) const [with T = Real]’:
# qss2.cpp:60:23:   required from here
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h:59:30: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Real, std::allocator<Real> >::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#    59 |  MASSERT(index >= 0 && index < this->values.size());
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/except.h:32:30: note: in definition of macro ‘MASSERT’
#    32 | #define MASSERT(lexp) if( !( lexp ) ) { AssertException e( "Invalid assertion" ) ; e.addText( #lexp ) ; e.addLocation( MEXCEPTION_LOCATION() ) ; throw e ; }
#       |                              ^~~~
# pmodeladm.cpp: In member function ‘virtual FlatCoupledCell& ParallelModelAdmin::newFlatCoupledCell(const string&)’:
# pmodeladm.cpp:232:18: warning: ‘coupled’ is used uninitialized in this function [-Wuninitialized]
#   232 |  add2DB( coupled );
#       |                  ^
# In file included from generat.cpp:18:
# generat.h: In constructor ‘Generator::Generator(const string&)’:
# generat.h:79:14: warning: ‘Generator::stop’ will be initialized after [-Wreorder]
#    79 |  const Port &stop;
#       |              ^~~~
# generat.h:78:8: warning:   ‘Port& Generator::out’ [-Wreorder]
#    78 |  Port &out ;
#       |        ^~~
# generat.cpp:62:1: warning:   when initialized here [-Wreorder]
#    62 | Generator::Generator( const string &name )
#       | ^~~~~~~~~
# idcell.cpp: In member function ‘virtual Model& InertialDelayCell::externalFunction(const MessageBag&)’:
# idcell.cpp:148:60: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#   148 |   if( (UseQuantum().Active() || UseDynQuantum().Active())  &&
#       |       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~
#   149 |     (*valueWithQuantum(*rc, QuantumValue()) != *valueWithQuantum(*rf, QuantumValue()) )
#       |     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tbool.h:21,
#                  from synnode.h:47,
#                  from synnode.cpp:21:
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h: In instantiation of ‘const T& Tuple<T>::operator[](int) const [with T = Real]’:
# synnode.cpp:413:23:   required from here
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h:59:30: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Real, std::allocator<Real> >::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#    59 |  MASSERT(index >= 0 && index < this->values.size());
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/except.h:32:30: note: in definition of macro ‘MASSERT’
#    32 | #define MASSERT(lexp) if( !( lexp ) ) { AssertException e( "Invalid assertion" ) ; e.addText( #lexp ) ; e.addLocation( MEXCEPTION_LOCATION() ) ; throw e ; }
#       |                              ^~~~
# In file included from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tbool.h:21,
#                  from synnode.h:47,
#                  from tuple_node.h:6,
#                  from tuple_node.cpp:4:
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h: In instantiation of ‘const T& Tuple<T>::operator[](int) const [with T = SyntaxNode*]’:
# tuple_node.cpp:38:35:   required from here
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h:59:30: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<SyntaxNode*>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#    59 |  MASSERT(index >= 0 && index < this->values.size());
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/except.h:32:30: note: in definition of macro ‘MASSERT’
#    32 | #define MASSERT(lexp) if( !( lexp ) ) { AssertException e( "Invalid assertion" ) ; e.addText( #lexp ) ; e.addLocation( MEXCEPTION_LOCATION() ) ; throw e ; }
#       |                              ^~~~
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h: In instantiation of ‘const T& Tuple<T>::operator[](int) const [with T = Real]’:
# tuple_node.cpp:101:55:   required from here
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/tuple_value.h:59:30: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Real>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#    59 |  MASSERT(index >= 0 && index < this->values.size());
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/except.h:32:30: note: in definition of macro ‘MASSERT’
#    32 | #define MASSERT(lexp) if( !( lexp ) ) { AssertException e( "Invalid assertion" ) ; e.addText( #lexp ) ; e.addLocation( MEXCEPTION_LOCATION() ) ; throw e ; }
#       |                              ^~~~
# pprocadm.cpp: In member function ‘ParallelProcessor& ParallelProcessorAdmin::generateProcessor(FlatCoupledCell*, ProcId)’:
# pprocadm.cpp:108:49: warning: ‘coord’ is used uninitialized in this function [-Wuninitialized]
#   108 |  coupled->processor( (ParallelProcessor*) coord );
#       |                                                 ^
# In file included from tbool.h:21,
#                  from real.h:22,
#                  from value.cpp:4:
# tuple_value.h: In instantiation of ‘const T& Tuple<T>::operator[](int) const [with T = Real]’:
# tuple_value.h:117:13:   required from ‘bool Tuple<T>::equals(const AbstractValue&) const [with T = Real]’
# tuple_value.h:107:6:   required from here
# tuple_value.h:59:30: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<Real, std::allocator<Real> >::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#    59 |  MASSERT(index >= 0 && index < this->values.size());
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/except.h:32:30: note: in definition of macro ‘MASSERT’
#    32 | #define MASSERT(lexp) if( !( lexp ) ) { AssertException e( "Invalid assertion" ) ; e.addText( #lexp ) ; e.addLocation( MEXCEPTION_LOCATION() ) ; throw e ; }
#       |                              ^~~~
# macroexp.cpp: In member function ‘int macroExpansion::isInclude(char*)’:
# macroexp.cpp:24:24: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#    24 | #define MACRO_INCLUDE  "#INCLUDE"
#       |                        ^~~~~~~~~~
# macroexp.cpp:285:32: note: in expansion of macro ‘MACRO_INCLUDE’
#   285 |  return isStringSimilar( line, MACRO_INCLUDE );
#       |                                ^~~~~~~~~~~~~
# macroexp.cpp: In member function ‘int macroExpansion::isInclude(char*, long int)’:
# macroexp.cpp:24:24: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#    24 | #define MACRO_INCLUDE  "#INCLUDE"
#       |                        ^~~~~~~~~~
# macroexp.cpp:290:41: note: in expansion of macro ‘MACRO_INCLUDE’
#   290 |  return isStringSimilar( line, posLine, MACRO_INCLUDE );
#       |                                         ^~~~~~~~~~~~~
# macroexp.cpp: In member function ‘int macroExpansion::isMacro(char*, long int)’:
# macroexp.cpp:25:22: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#    25 | #define MACRO_MACRO  "#MACRO"
#       |                      ^~~~~~~~
# macroexp.cpp:295:41: note: in expansion of macro ‘MACRO_MACRO’
#   295 |  return isStringSimilar( line, posLine, MACRO_MACRO );
#       |                                         ^~~~~~~~~~~
# macroexp.cpp: In member function ‘int macroExpansion::isBeginOfMacro(char*)’:
# macroexp.cpp:26:26: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#    26 | #define MACRO_BEGINMACRO "#BEGINMACRO"
#       |                          ^~~~~~~~~~~~~
# macroexp.cpp:300:32: note: in expansion of macro ‘MACRO_BEGINMACRO’
#   300 |  return isStringSimilar( line, MACRO_BEGINMACRO );
#       |                                ^~~~~~~~~~~~~~~~
# macroexp.cpp: In member function ‘int macroExpansion::isEndOfMacro(char*)’:
# macroexp.cpp:27:25: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#    27 | #define MACRO_ENDMACRO  "#ENDMACRO"
#       |                         ^~~~~~~~~~~
# macroexp.cpp:305:32: note: in expansion of macro ‘MACRO_ENDMACRO’
#   305 |  return isStringSimilar( line, MACRO_ENDMACRO );
#       |                                ^~~~~~~~~~~~~~
# real.cpp: In constructor ‘Real::Real(Value)’:
# real.cpp:191:3: warning: case label value is less than minimum value for type
#   191 |   case -1: rvalue = M_MINFINITO;
#       |   ^~~~
# real.cpp:187:9: warning: switch condition has boolean value [-Wswitch-bool]
#   187 |  switch (isInfinite(Valor)) {
#       |         ^
# VTime.cpp: In function ‘std::istream& operator>>(std::istream&, VTime&)’:
# VTime.cpp:313:1: warning: no return statement in function returning non-void [-Wreturn-type]
#   313 | }
#       | ^
# DebugStream.cpp: In member function ‘virtual void DebugStream::interact()’:
# DebugStream.cpp:682:31: warning: ‘char* gets(char*)’ is deprecated [-Wdeprecated-declarations]
#   682 |     char *result = gets(buffer);
#       |                               ^
# In file included from /usr/include/c++/9/cstdio:42,
#                  from /usr/include/c++/9/ext/string_conversions.h:43,
#                  from /usr/include/c++/9/bits/basic_string.h:6493,
#                  from /usr/include/c++/9/string:55,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common/VTime.h:20,
#                  from DefaultVTime.h:35,
#                  from SimulationTime.h:30,
#                  from BasicEvent.h:31,
#                  from LogicalProcess.h:30,
#                  from DebugStream.cpp:31:
# /usr/include/stdio.h:577:14: note: declared here
#   577 | extern char *gets (char *__s) __wur __attribute_deprecated__;
#       |              ^~~~
# DebugStream.cpp:682:31: warning: ‘char* gets(char*)’ is deprecated [-Wdeprecated-declarations]
#   682 |     char *result = gets(buffer);
#       |                               ^
# In file included from /usr/include/c++/9/cstdio:42,
#                  from /usr/include/c++/9/ext/string_conversions.h:43,
#                  from /usr/include/c++/9/bits/basic_string.h:6493,
#                  from /usr/include/c++/9/string:55,
#                  from /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common/VTime.h:20,
#                  from DefaultVTime.h:35,
#                  from SimulationTime.h:30,
#                  from BasicEvent.h:31,
#                  from LogicalProcess.h:30,
#                  from DebugStream.cpp:31:
# /usr/include/stdio.h:577:14: note: declared here
#   577 | extern char *gets (char *__s) __wur __attribute_deprecated__;
#       |              ^~~~
# BasicEvent.cpp: In constructor ‘BasicEvent::BasicEvent(const BasicEvent*)’:
# BasicEvent.cpp:58:38: warning: ‘void* memcpy(void*, const void*, size_t)’ writing to an object of type ‘class BasicEvent’ with no trivial copy-assignment; use copy-assignment or copy-initialization instead [-Wclass-memaccess]
#    58 |   memcpy(this, be, sizeof(BasicEvent));
#       |                                      ^
# In file included from BasicEvent.cpp:30:
# BasicEvent.h:34:7: note: ‘class BasicEvent’ declared here
#    34 | class BasicEvent {
#       |       ^~~~~~~~~~
# CommManager.cpp: In member function ‘virtual void CommManager::recvEvent(BasicEvent*)’:
# CommManager.cpp:152:50: warning: ‘void* memcpy(void*, const void*, size_t)’ writing to an object of type ‘class BasicEvent’ with no trivial copy-assignment; use copy-assignment or copy-initialization instead [-Wclass-memaccess]
#   152 |  memcpy((BasicEvent *) mpiMsg, event, event->size);
#       |                                                  ^
# In file included from KernelMsgs.h:31,
#                  from CommManager.h:32,
#                  from CommManager.cpp:31:
# BasicEvent.h:34:7: note: ‘class BasicEvent’ declared here
#    34 | class BasicEvent {
#       |       ^~~~~~~~~~
# CommManager.cpp: In member function ‘void CommManager::routeMsg(BasicMsg*)’:
# CommManager.cpp:304:62: warning: ‘void* memcpy(void*, const void*, size_t)’ writing to an object of type ‘class BasicEvent’ with no trivial copy-assignment; use copy-assignment or copy-initialization instead [-Wclass-memaccess]
#   304 |     memcpy(toDeliver, (BasicEvent *) eventMsg, eventMsg->size);
#       |                                                              ^
# In file included from KernelMsgs.h:31,
#                  from CommManager.h:32,
#                  from CommManager.cpp:31:
# BasicEvent.h:34:7: note: ‘class BasicEvent’ declared here
#    34 | class BasicEvent {
#       |       ^~~~~~~~~~
# /usr/bin/ld: /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/bin/libsimu.a(macroexp.o): in function `macroExpansion::expand[abi:cxx11]()':
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/macroexp.cpp:147: warning: the use of `tmpnam' is dangerous, better use `mkstemp'
# /usr/bin/ld: warped/notime/obj/DebugStream.o: in function `DebugStream::interact()':
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime/DebugStream.cpp:682: warning: the `gets' function is dangerous and should not be used.

# %% [markdown]
# Una vez que termina se crea el subdirectorio `bin` contendrá el archivo ejecutable cd++:

# %%
# %%bash -s "$CDPP_SRC"
#
# cd $1/bin
#
# ls
# Out:
# cd++
# libsimu.a

# %% [markdown]
# <a id='simuladorCD++'></a>
# # Simulador CD++
#
# Una vez instalado interactuamos con el simulador por línea de comandos. Para ver la ayuda del simulador lo invocamos con la opción `-h`:

# %%
# %%bash -s "$CDPP_SRC"
#
# cd $1
#
# bin/cd++ -h
# Out:
# bin/cd++ [-ehlmotdpvbfrsqw]
# 	e: events file (default: none)
# 	h: show this help
# 	l: logs all messages to a log file (default: /dev/null)
# 	L[I*@XYDS]: log modifiers (logs only the specified messages)
# 	m: model file (default : model.ma)
# 	o: output (default: /dev/null)
# 	t: stop time (default: Infinity)
# 	d: set tolerance used to compare real numbers
# 	p: print extra info when the parsing occurs (only for cells models)
# 	D: partition details file (default: /dev/null)
# 	P: parallel partition file (will run parallel simulation)
# 	v: evaluate debug mode (only for cells models)
# 	b: bypass the preprocessor (macros are ignored)
# 	f: flat debug mode (only for flat cells models)
# 	r: debug cell rules mode (only for cells models)
# 	s: show the virtual time when the simulation ends (on stderr)
# 	q: use quantum to compute cell values
# 	y: use dynamic quantum (strategy 1) to compute cells values
# 	Y: use dynamic quantum (strategy 2) to compute cells values
# 	w: sets the width and precision (with form xx-yy) to show numbers

# %% [markdown]
# En los ejemplos que siguen vamos a utilizar los parámetros:
#
# * `-m` para pasarle el modelo a simular
# * `-t` tiempo final de la simulación. Formato **HH:MM:SS:MS**:
#   * HH: cantidad de horas
#   * MM: minutos (0 a 59)
#   * SS: segundos (0 a 59)
#   * MS: milisegundos (0 a 999)
# * `-e` para pasarle un archivo con eventos de la o las entradas del modelo
# * `-l` para indicarle dónde queremos almacenar los mensajes intercambiados internamente por los modelos atómicos y acoplados
# * `-o` para indicarle dónde queremos almacenar la información de la o las salidas del modelo

# %% [markdown]
# <a id='ejemplosCD++'></a>
#
# # Ejemplos en CD++

# %% [markdown]
# Con el simulador vienen algunos ejemplos en `examples/`:

# %%
CDPP_EXAMPLES = CDPP_DIR.joinpath('examples')

# podemos ver el contenido de la variable de entorno
# print(CDPP_EXAMPLES)

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1
#
# ls
# Out:
# addconstant
# addconstant.zip
# const_generator (copy)
# fake_news_generator
# generator
# media
# population
# pulse
# qss
# semaforo
# semaforo_old
# semaforo.zip
# SimpleNetwork
# SimpleNetwork.zip
# teacup
# teacup_old
# teacup.zip
# template
# template.zip
# transducer
# transducer.zip

# %% [markdown]
# * **Generador de eventos periódicos (*const_generator*):** Generador que produce eventos periódicos con una entrada de _stop_ y una salida. La frecuencia de los eventos se define por medio de un parámetro _frequency_.
# * **Generador de eventos aleatorios (*generator*):** Generador que produce eventos cada un tiempo aleatorio y cuya salida toma valores que se incrementan con cada evento a partir de un valor inicial. Tiene una única entrada de _stop_ y parámetros: _distribution_, _initial_, _increment_ correspondientes a la distribución de los eventos, el valor inicial de la salida y el incremento del valor del evento de salida respectivamente.
# * **Pulsos (*pulse*):** Generador de eventos periódicos de eventos con dos entradas: _start_ y _stop_ y una salida. Los eventos de salida toman un valor aleatorio distribuido de forma uniforme entre $0$ y $1$.
# * **QSS (*qss*):** Se trata de dos integradores conectados de forma circular que evolucionan a partir de condiciones iniciales:
# \begin{align*}
#     \dot{x}(t) &= y(t)\\
#     \dot{y}(t) &= -x(t)
# \end{align*}

# %% [markdown]
# <a id='scripts'></a>
#
# # Scripts útiles
#
# En la carpeta `scripts/` pueden encontrar el script `tuple_to_real.py` que utilzaremos para convertir un archivo con tuplas de valores en un achivo de reales:

# %%
# %%bash -s "$CDPP_DIR"
#
# cd $1/scripts
#
# ls
# Out:
# __pycache__
# tuple_to_real.py

# %% [markdown]
# <a id='holamundo'></a>
#
# # Ejemplo _Hola Mundo!_
#
# Tomemos el ejemplo **Pulse** en `examples/pulse/`. Vamos a ejecutar esta simulación para verificar que el simulador se instaló correctamente.

# %% [markdown]
# ## Descripción del modelo (modelo conceptual)
#
# * Este modelo atómico genera internamente eventos a intervalos regulares
# * Tiene dos entradas _start_ y _stop_
# * Tiene una única salida _out_
# * El valor de los eventos de salida sigue una distribución uniforme entre $0$ y $100$

# %% [markdown]
# <center><img src="data:image/svg+xml;base64,..." width="300"></center>

# %% [markdown]
# ## Simulador y modelo por separado
#
# ### Modelo: modelo acoplado y componentes

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd '../model/'
#
# cat fakeNewsPropagationAmalia.ma
# Out:
# [top]
# components : fakenewsgenerator@fakenewsgenerator mediaOfficial@media mediaOpposition@media populationscoupled
# out : out_port
# in : stop
# link : stop stop@fakenewsgenerator
# link : out@fakenewsgenerator in@mediaOfficial
# link : out@fakenewsgenerator in@mediaOpposition
# link : out@mediaOfficial in@populationscoupled
# link : out@mediaOpposition in@populationscoupled
#
# [fakenewsgenerator]
# frequency : 00:00:01:00
#
# [mediaOfficial]
# party : 1
#
# [mediaOpposition]
# party : 0
#
# [populationscoupled]
# components : socialnetwork@socialnetwork population1@population population2@population population3@population population4@population
# out : out_port
# in : news
# link : news in@population1
# link : news in@population2
# link : news in@population3
# link : news in@population4
# link : out@population1 in@socialnetwork
# link : out@population2 in@socialnetwork
# link : out@population3 in@socialnetwork
# link : out@population4 in@socialnetwork
# link : out@socialnetwork in@population1
# link : out@socialnetwork in@population2
# link : out@socialnetwork in@population3
# link : out@socialnetwork in@population4
#
# [population1]
# population_id : 1
# age : 20
# university_studies : 0
# political_involvement : 0.9
# employment_status : 0.1
# economic_status : 0.4
# centrality : 0.8
#
# [population2]
# population_id : 2
# age : 35
# university_studies : 1
# political_involvement : 0.6
# employment_status : 0.6
# economic_status : 0.5
# centrality : 0.6
#
# [population3]
# population_id : 3
# age : 50
# university_studies : 1
# political_involvement : 0.5
# employment_status : 0.8
# economic_status : 0.7
# centrality : 0.3
#
# [population4]
# population_id : 4
# age : 75
# university_studies : 0
# political_involvement : 0.2
# employment_status : 0.2
# economic_status : 0.4
# centrality : 0.1

# %% [markdown]
# ### Simulador CD++

# %% [markdown]
# Por medio de `make` compilamos el modelo:

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# ls
#
# cd '../src/'
#
# #make clean
#
# make -j4
# Out:
# 00 - primeros_pasos_resultados_2021-Copy1.ipynb
# make -C ../../../SED/CDPP_ExtendedStates-codename-Santi/src/cd++ cd++ OUT_DIR=/home/matias/Desktop/fakeNewsPropagator/src/bin MODEL_FLAGS=-DREGISTER_ATOMICS
# make[1]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics'
# make -C cpu OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make -C queue OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make -C qss OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu'
# make -C generator OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell'
# make -C transducer OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc'
# make -C math OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model'
# make -C state OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg'
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser'
# make -C cdlang OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc'
# make -C state OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim'
# make clean
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils'
# make -C log OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim'
# make -C loader clean OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[4]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader'
# make[4]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val'
# make -C /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim'
# make -C loader OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main'
# make[2]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped'
# make -C common OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make -C notime OBJ_DIR=obj SRC_DIR=/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common'
# make[3]: Entering directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped'
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj  -DREGISTER_ATOMICS -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  stdaload.cpp -o obj/stdaload.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj  -DREGISTER_ATOMICS -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  parser.cpp -o obj/parser.o
# g++ -c -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/cpu/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/qss/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/generator/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/transducer/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/atomics/queue/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/msg/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/main/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/common/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/misc/math/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/model/state/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/proc/state/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/cell/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/log/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/val/obj -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt -I/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/evt/obj  -DREGISTER_ATOMICS -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  gram.c -o obj/gram.o
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim/loader'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/sim'
# make[3]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser/cdlang'
# make[2]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/parser'
# g++ -L/home/matias/Desktop/fakeNewsPropagator/src/bin -o /home/matias/Desktop/fakeNewsPropagator/src/bin/cd++ main/obj/main.o warped/common/obj/VTime.o warped/notime/obj/BasicState.o warped/notime/obj/InputQueue.o warped/notime/obj/BasicNoTime.o warped/notime/obj/LogicalProcess.o warped/notime/obj/BasicEvent.o warped/notime/obj/Interactive.o warped/notime/obj/DebugStream.o warped/notime/obj/FileQueue.o warped/notime/obj/KernelMsgs.o warped/notime/obj/NoTime.o warped/notime/obj/CommManager.o warped/notime/obj/NoTimeObject.o /home/matias/Desktop/fakeNewsPropagator/src/bin/reg.o /home/matias/Desktop/fakeNewsPropagator/src/bin/SocialNetworks.o /home/matias/Desktop/fakeNewsPropagator/src/bin/FakeNewsGenerator.o /home/matias/Desktop/fakeNewsPropagator/src/bin/CoupledPopulation.o /home/matias/Desktop/fakeNewsPropagator/src/bin/Media.o /home/matias/Desktop/fakeNewsPropagator/src/bin/Population.o -lsimu
# make[1]: Leaving directory '/home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++'
# /usr/bin/ld: /home/matias/Desktop/fakeNewsPropagator/src/bin/libsimu.a(macroexp.o): in function `macroExpansion::expand[abi:cxx11]()':
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/utils/macroexp.cpp:147: warning: the use of `tmpnam' is dangerous, better use `mkstemp'
# /usr/bin/ld: warped/notime/obj/DebugStream.o: in function `DebugStream::interact()':
# /home/matias/SED/CDPP_ExtendedStates-codename-Santi/src/cd++/warped/notime/DebugStream.cpp:682: warning: the `gets' function is dangerous and should not be used.

# %% [markdown]
# Si todo fue bien, ahora tenemos un directorio `bin` dentro de `examples/pulse/src/` que es una versión del simulador que incluye el modelo atómico `pulse`:

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# ls
# cd '../src/'
#
# # para ver dónde estamos paradxs
# pwd
#
# ls bin
# Out:
# 00 - primeros_pasos_resultados_2021-Copy1.ipynb
# /home/matias/Desktop/fakeNewsPropagator/src
# cd++
# CoupledPopulation.o
# FakeNewsGenerator.o
# libsimu.a
# Media.o
# Population.o
# reg.o
# SocialNetworks.o

# %% [markdown]
# ## Simulación del modelo en CD++

# %% [markdown]
# El archivo de eventos de entrada `pulse.ev` contiene los eventos externos enviados a los puertos de entrada del modelo acoplado de jerarquía superior (_top model_).
#
# Los eventos tienen una etiqueta de tiempo con formato VTime: HH:MM:SS:MS.
#
# Podemos ver varios eventos externos enviados al puerto de entrada _start_ entre los instantes 00:00:00:15 y 00:02:08:45.
#
# Podemos ver el evento de terminación enviado al puerto de entrada _stop_ del modelo en el instante 00:05:00:00.

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd '../model/'
# ls
# head fakeNewsPropagation.ev
# Out:
# fakeNewsPropagationAmalia.ma
# fakeNewsPropagation.ev
# fakeNewsPropagation.ma
# 00:10:00:00 stop 1

# %% [markdown]
# Ahora podemos ejecutar la simulación usando la descripción en el subdirectorio `model`:

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd '../src/'
#
# bin/cd++ -m ../model/fakeNewsPropagationAmalia.ma  \
#          -e ../model/fakeNewsPropagation.ev  \
#          -l ../fakeNewsPropagation.log \
#          -o ../fakeNewsPropagation.out
# Out:
# PCD++: A Tool to Implement n-Dimensional Cell-DEVS models
# Version 3.0 - March 2003
# Troccoli A., Rodriguez D., Wainer G., Barylko A., Beyoglonian J., Lopez A.
# -----------------------------------------------------------------------------
# PCD++ Extended States: An extended and improved version of CD++ for Cell-DEVS
# Version 4.1.2 - December 2018
# Santi L., Castro, R., Pimás, J.
# -----------------------------------------------------------------------------
# Discrete Event Simulation Lab
# Departamento de Computación
# Facultad de Ciencias Exactas y Naturales
# Universidad de Buenos Aires, Argentina
# -----------------------------------------------------------------------------
# Compiled for standalone simulation
#
#
# Loading models from ../model/fakeNewsPropagationAmalia.ma
# Loading events from ../model/fakeNewsPropagation.ev
# Running parallel simulation. Reading models partition from
# Model partition details output to: /dev/null*
# Message log: ../fakeNewsPropagation.log
# Output to: ../fakeNewsPropagation.out
# Tolerance set to: 1e-08
# Configuration to show real numbers: Width = 12 - Precision = 5
# Quantum: Not used
# Evaluate Debug Mode = OFF
# Flat Cell Debug Mode = OFF
# Debug Cell Rules Mode = OFF
# Temporary File created by Preprocessor = /tmp/fileJXbZT0
# Printing parser information = OFF
#
# Stop at time: Infinity.
# LP 0: initializing simulation objects
# 00:10:00:000:0 / stop /      1.00000
# LP 0: starting simulation (NoTime).
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:01:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:01:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:02:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:02:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:03:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:03:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:04:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:04:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:05:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:05:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:06:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:06:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:07:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:07:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:08:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:08:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:09:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:09:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:10:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:10:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:11:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:11:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:12:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:12:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:13:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:13:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:14:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:14:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:15:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:15:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:16:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:16:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:17:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:17:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:18:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:18:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:19:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:19:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:00:20:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:20:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:00:20:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:20:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:20:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:20:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:20:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:00:20:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# ...
# dext@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:54:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:54:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:54:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:54:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:54:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:54:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:54:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:54:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:55:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:55:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:56:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:56:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:57:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:57:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:58:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:58:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:09:59:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:09:59:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dint@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:01:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dext@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:01:000:0 - sigma: 00:00:01:000:0
# Guarda, tiempo negativo!
# dint@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dint@00:10:00:000:0 - timeleft: 00:00:00:000:0 - elapsed: 00:00:00:000:0 - sigma: 00:00:00:000:0
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# dext@00:10:00:000:0 - timeleft: ... - elapsed: 00:00:00:000:0 - sigma: ...
# Simulation complete!
# Simulation ended!
# LP 0 has finished simulation

# %% [markdown]
# Podemos notar que no estamos usando la opción `-t` porque la simulación termina por el evento de entrada en el puerto _stop_.

# %% [markdown]
# ## Análisis de los resultados
#
# Veamos los eventos generados en la salida del atómico en el archivo _out_. Recordemos que los valores de los eventos son tupla de 3 elementos.

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/population/
#
# head population.out
# Out:
# 00:10:00:000:0 out_port [1, 1, 1, 1, 1, 100, 0, 1, 0, 1, 1, 0.6875, 1]

# %% [markdown]
# Veamos el contenido de los archivos de _log_ de mensajes:

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/pulse/
#
# cat pulse.log
# Out:
# [logfiles]
# ParallelRoot : ../pulse.log00
# top : ../pulse.log02
# pulse : ../pulse.log01

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/pulse/
#
# head pulse.log00
# Out:
# 0 / L / D / 00:00:00:000:0 / top(02) / 00:00:05:000:0 / ParallelRoot(00)
# 0 / L / D / 00:00:00:015:0 / top(02) / 00:00:05:000:0 / ParallelRoot(00)
# 0 / L / D / 00:00:00:030:0 / top(02) / 00:00:05:000:0 / ParallelRoot(00)
# 0 / L / D / 00:00:00:045:0 / top(02) / 00:00:05:000:0 / ParallelRoot(00)
# 0 / L / D / 00:00:01:020:0 / top(02) / 00:00:05:000:0 / ParallelRoot(00)
# 0 / L / D / 00:00:01:040:0 / top(02) / 00:00:05:000:0 / ParallelRoot(00)
# 0 / L / D / 00:00:03:010:0 / top(02) / 00:00:05:000:0 / ParallelRoot(00)
# 0 / L / D / 00:00:04:045:0 / top(02) / 00:00:05:000:0 / ParallelRoot(00)
# 0 / L / Y / 00:00:09:045:0 / top(02) / out_port / [32, 0, 1, 2] / ParallelRoot(00)
# 0 / L / D / 00:00:09:045:0 / top(02) / 00:00:00:000:0 / ParallelRoot(00)

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/pulse/
#
# head pulse.log01
# Out:
# 0 / L / I / 00:00:00:000:0 / top(02) / pulse(01)
# 0 / L / X / 00:00:00:015:0 / top(02) / start /      1.00000 / pulse(01)
# 0 / L / * / 00:00:00:015:0 / top(02) / pulse(01)
# 0 / L / X / 00:00:00:030:0 / top(02) / start /      1.00000 / pulse(01)
# 0 / L / * / 00:00:00:030:0 / top(02) / pulse(01)
# 0 / L / X / 00:00:00:045:0 / top(02) / start /      1.00000 / pulse(01)
# 0 / L / * / 00:00:00:045:0 / top(02) / pulse(01)
# 0 / L / X / 00:00:01:020:0 / top(02) / start /      1.00000 / pulse(01)
# 0 / L / * / 00:00:01:020:0 / top(02) / pulse(01)
# 0 / L / X / 00:00:01:040:0 / top(02) / start /      1.00000 / pulse(01)

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/pulse/
#
# head pulse.log02
# Out:
# 0 / L / I / 00:00:00:000:0 / ParallelRoot(00) / top(02)
# 0 / L / D / 00:00:00:000:0 / pulse(01) / 00:00:01:000:0 / top(02)
# 0 / L / X / 00:00:00:015:0 / ParallelRoot(00) / start /      1.00000 / top(02)
# 0 / L / * / 00:00:00:015:0 / ParallelRoot(00) / top(02)
# 0 / L / D / 00:00:00:015:0 / pulse(01) / 00:00:01:000:0 / top(02)
# 0 / L / X / 00:00:00:030:0 / ParallelRoot(00) / start /      1.00000 / top(02)
# 0 / L / * / 00:00:00:030:0 / ParallelRoot(00) / top(02)
# 0 / L / D / 00:00:00:030:0 / pulse(01) / 00:00:01:000:0 / top(02)
# 0 / L / X / 00:00:00:045:0 / ParallelRoot(00) / start /      1.00000 / top(02)
# 0 / L / * / 00:00:00:045:0 / ParallelRoot(00) / top(02)

# %% [markdown]
# Graficamos los resultados que obtuvimos en el archivo `pulse.out`:

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd ..
# ls
# Out:
# README.md
# fakeNewsPropagation.out
# model
# notebook
# src
# test

# %%
try:
    import pandas as pd
except:
    # !pip install pandas
    import pandas as pd
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-0.24.2-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 4.9 MB/s
# Collecting numpy>=1.12.0
#   Downloading numpy-1.16.6-cp27-cp27m-macosx_10_9_x86_64.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 7.8 MB/s
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/amaliasorondo/Library/Python/2.7/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2011k in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from pandas) (2013.7)
# Requirement already satisfied: six>=1.5 in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Installing collected packages: numpy, pandas
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# matplotlib 1.3.1 requires nose, which is not installed.
# Successfully installed numpy-1.16.6 pandas-0.24.2
# WARNING: You are using pip version 20.2.4; however, version 20.3.4 is available.
# You should consider upgrading via the '/System/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python -m pip install --upgrade pip' command.

# %%
try:
    import scipy as sp
except:
    # !pip install scipy
    import scipy as sp

# %%
try:
    import matplotlib.pyplot as plt
except:
    # !pip install matplotlib
    import matplotlib.pyplot as plt

# %%
OUT_FILENAME = "/../fakeNewsPropagation.out"

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# head ../fakeNewsPropagation.out
# Out:
# 00:00:01:018:0 out_port [1, 0.532255, 0, 0, 35, 1, 0.6, 0.6, 0.5, 0.6, 0.291532, 2, 1]
# 00:00:01:035:0 out_port [3, 0.995788]
# 00:00:02:035:0 out_port [0, 0.801755, 0.087965, 0, 75, 0, 0.2, 0.2, 0.4, 0.1, 0.673715, 4, 0.722025]
# 00:00:02:051:0 out_port [3, 0.96785]
# 00:00:03:001:0 out_port [0, 0.188523, 0.65642, 0, 35, 1, 0.6, 0.6, 0.5, 0.6, 0.455618, 2, 0.904582]
# 00:00:03:015:0 out_port [3, 0.881442]
# 00:00:04:003:0 out_port [0, 0.858278, 0.28985, 0, 35, 1, 0.6, 0.6, 0.5, 0.6, 0.493516, 2, 0.724906]
# 00:00:04:007:0 out_port [1, 0.756534]
# 00:00:05:007:0 out_port [0, 0.682556, 0.732951, 0, 50, 1, 0.5, 0.8, 0.7, 0.3, 0.489438, 3, 0.689123]
# 00:00:05:024:0 out_port [1, 0.716727]

# %%
# definimos los path a los archivos de interés
OUT_FILENAME = "../fakeNewsPropagation.out"

# con el script tuple_to_real elegimos el índice 0 de la 3-upla
# tuple_to_real.tuple_to_real(OUT_FILENAME, 0)

# definimos los nombres de las columnas en los dataframes de pandas
TIME_COL_ORIG = 'time_orig'
TIME_COL = 'time'
PORT_COL = 'port'
VALUE_COL_ORIG = 'value_orig'
VALUE_COL = 'value'
MESSAGE_TYPE_COL = 'message_type'
MODEL_ORIGIN_COL = 'model_origin'
MODEL_DEST_COL = 'model_dest'

# parsea cada fila del dataframe
def parse_value(value: str):
    is_list = value.strip().startswith("[") and value.strip().endswith("]")
    if is_list:
        return tuple(float(num) for num in value.replace('[', '').replace(']', '').split(', '))
    return float(value)

# conversion VTime a float
def time_to_secs(time):
    h, m, s, ms, r = time.split(':')
    return float(h)*60*60. + float(m)*60. + float(s) + float(ms)/1000. + float(r)/1000.

# df_converters = {
#     VALUE_COL: parse_value,
#     TIME_COL: time_to_secs
# }

salida = pd.read_csv(OUT_FILENAME,
                     delimiter=r'(?<!,)\s+',
                     engine='python',  # C engine doesnt work for regex
                     # Se puede usar esto para convertir los valores directamente:
                     # converters=df_converters,
                     names=[TIME_COL_ORIG, PORT_COL, VALUE_COL_ORIG]
                    )

salida[TIME_COL]  = salida.apply(lambda row: time_to_secs(row[TIME_COL_ORIG]), axis=1)
salida[VALUE_COL] = salida.apply(lambda row: parse_value(str(row[VALUE_COL_ORIG])), axis=1)

salida.head()
# Out:
#   File "<ipython-input-18-627488381f1a>", line 18
#     def parse_value(value: str):
#                          ^
# SyntaxError: invalid syntax

# %%
y_values,_,_ = salida[VALUE_COL].str
x_values = salida[TIME_COL]

plt.figure(figsize=(10,5))
plt.plot(x_values, y_values,marker='x')
plt.grid(True)
plt.xlabel('Tiempo [s]')
plt.ylabel('Valor')
plt.title('Eventos de salida del modelo generator');

# %% [markdown]
# Podemos observar que el último evento se produjo aproximadamente a los $300~\text{s}$, es decir, 00:05:00:000.

# %%
import scipy.stats as sps

plt.figure(figsize=(10,5))

# histograma de los eventos de salida
n, bins, patches = plt.hist(y_values, 20, density=True, facecolor='g', alpha=0.75)

# funcion de densidad de probabilidad teorica
u = sps.uniform.pdf(bins, loc=0, scale=100)
plt.plot(bins,u,'r',linewidth=2)

plt.xlabel('Tiempo eventos')
plt.ylabel('Probabilidad')
plt.title('Histograma del tiempo entre eventos de salida')
plt.grid(True)

# %% [markdown]
# # Consideraciones importantes de CD++
#
# ## Simulación de un modelo atómico _ad-hoc_
#
# Para esto sugerimos tomar como base el ejemplo pulse incluído en el proyecto (ver `examples/pulse/src`).
# En particular, es importante incluir un Makefile que defina al menos:
#
#  * La variable `KERNEL_SRC` apuntando al directorio en donde se ubica el código fuente de cd++.
#  * La variable `MODEL_FLAGS` con valor `-DREGISTER_ATOMICS`. Esta es para compilar el código responsable de registrar el modelo atómico deseado en el _kernel_ del simulador.
#  * La inclusión de definiciones y reglas de compilación provistas para el simulador:
#
# ```
#     include $(KERNEL_SRC)/Makefile.rules
#     include $(KERNEL_SRC)/Makefile.defs
# ```
#
# También es importante incluir una implementación de la función:
#
# ```C++
# void register_atomics_on(ParallelModelAdmin &admin)
# ```
#
# cuyo propósito es registrar en el _kernel_ los modelos atómicos que se quieren usar. En general, es suficiente con incluir una línea como la que sigue:
#
# ```C++
# admin.registerAtomic(NewAtomicFunction<ModelClass>(), "Model name");
# ```

# %% [markdown]
# Si miramos el contenido del archivo `reg.cpp`, veremos cómo se regitra el modelo en el kernel del simulador:

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/pulse/src/
#
# cat reg.cpp
# Out:
# #include "pmodeladm.h"
# #include "register.h"
#
# #include "pulse.h"
#
#
# void register_atomics_on(ParallelModelAdmin &admin)
# {
# 	admin.registerAtomic(NewAtomicFunction<Pulse>(), ATOMIC_MODEL_NAME);
# }

# %% [markdown]
# Aquí `Pulse` es el nombre de la clase que implementa nuestro modelo y la macro `ATOMIC_MODEL_NAME` define su nombre (el cual tiene que ser único).
